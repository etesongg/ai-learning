# %% [markdown]
# # 덧셈 규칙 학습

# %%
import warnings
warnings.filterwarnings('ignore', module='requests')

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
#from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# ## 데이터 준비

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
file_path = './dataset/addition.txt'

# %%
questions, answers = [], []
# todo
for line in open(file_path, 'r'):
    idx = line.find('_')
    questions.append(line[:idx])
    answers.append(line[idx:-1])

# %%
len(questions), len(answers)
# Out:
# (50000, 50000)

# %%
# 최대 길이 계산
MAX_QUESTION_LEN = max(len(q) for q in questions) # 7
MAX_ANSWER_LEN = max(len(a) for a in answers) # 5

MAX_QUESTION_LEN, MAX_ANSWER_LEN
# Out:
# (7, 5)

# %% [markdown]
# ### 어휘사전(Vocabulary)

# %%
class Vocabulary:
    def __init__(self, questions, answers):
        self.char_to_id = {}
        self.id_to_char = {}
        self.idx = 0

        for question in questions:
            self.add_char(question)
        for answer in answers:
            self.add_char(answer)

    def add_char(self, text):
        for char in text:
            # todo
            if char not in self.char_to_id:
                self.char_to_id[char] = self.idx
                self.id_to_char[self.idx] = char
                self.idx += 1

    def __len__(self): # vocab.__len__() ---> len(vocab)
        return len(self.char_to_id)

# %%
# Vocabulary 생성
vocab = Vocabulary(questions, answers)

# %%
vocab.__len__(), len(vocab)
# Out:
# (13, 13)

# %%
VOCAB_SIZE = len(vocab)
VOCAB_SIZE
# Out:
# 13

# %%
vocab.char_to_id
# Out:
# {'1': 0,
#  '6': 1,
#  '+': 2,
#  '7': 3,
#  '5': 4,
#  ' ': 5,
#  '2': 6,
#  '0': 7,
#  '3': 8,
#  '9': 9,
#  '8': 10,
#  '4': 11,
#  '_': 12}

# %%
vocab.id_to_char
# Out:
# {0: '1',
#  1: '6',
#  2: '+',
#  3: '7',
#  4: '5',
#  5: ' ',
#  6: '2',
#  7: '0',
#  8: '3',
#  9: '9',
#  10: '8',
#  11: '4',
#  12: '_'}

# %% [markdown]
# ### Dataset

# %%
# 케라스의 tokenizer.texts_to_sequences(text_data) 역할
question_sequences = [[vocab.char_to_id[c] for c in q] for q in questions]
answer_sequences = [[vocab.char_to_id[c] for c in a] for a in answers]

# 패딩으로 고정길이 만들기
encoder_input = pad_sequences(question_sequences, maxlen=MAX_QUESTION_LEN, padding='post')
decoder_data = pad_sequences(answer_sequences, maxlen=MAX_ANSWER_LEN, padding='post')

decoder_input = decoder_data[:, :-1]
decoder_target = decoder_data[:, 1:]

# %%
encoder_input[0], decoder_input[0], decoder_target[0]
# Out:
# (array([0, 1, 2, 3, 4, 5, 5]), array([12,  9,  0,  5]), array([9, 0, 5, 5]))

# %%
# 질문
for i in encoder_input[0]:
    i = int(i)
    char = vocab.id_to_char[i]
    print(char, end='')
print()

# 답변 (input)
for i in decoder_input[0]:
    i = int(i)
    char = vocab.id_to_char[i]
    print(char, end='')
print()

# 답변 (target)
for i in decoder_target[0]:
    i = int(i)
    char = vocab.id_to_char[i]
    print(char, end='')
# Out:
# 16+75
# _91
# 91

# %%
def prepare_dataset(questions, answers, vocab, max_question_len, max_answer_len):
    # 케라스의 tokenizer.texts_to_sequences(text_data) 역할

    # 입력 데이터 반전용
    reversed_questions = [q[::-1] for q in questions]
    question_sequences = [[vocab.char_to_id[c] for c in q] for q in reversed_questions]

    # question_sequences = [[vocab.char_to_id[c] for c in q] for q in questions]
    answer_sequences = [[vocab.char_to_id[c] for c in a] for a in answers]

    # 패딩으로 고정길이 만들기
    encoder_input = pad_sequences(question_sequences, maxlen=MAX_QUESTION_LEN, padding='post')
    decoder_data = pad_sequences(answer_sequences, maxlen=MAX_ANSWER_LEN, padding='post')

    decoder_input = decoder_data[:, :-1]
    decoder_target = decoder_data[:, 1:]

    return encoder_input, decoder_input, decoder_target

# %%
# 데이터 분할
train_questions, test_questions, train_answers, test_answers = train_test_split(
    questions, answers, test_size=0.1, random_state=42
)
train_questions, val_questions, train_answers, val_answers = train_test_split(
    train_questions, train_answers, test_size=0.1, random_state=42
)

# %%
# 데이터셋 준비
train_encoder_input, train_decoder_input, train_decoder_target = prepare_dataset(
    train_questions, train_answers, vocab, MAX_QUESTION_LEN, MAX_ANSWER_LEN
)
val_encoder_input, val_decoder_input, val_decoder_target = prepare_dataset(
    val_questions, val_answers, vocab, MAX_QUESTION_LEN, MAX_ANSWER_LEN
)
test_encoder_input, test_decoder_input, test_decoder_target = prepare_dataset(
    test_questions, test_answers, vocab, MAX_QUESTION_LEN, MAX_ANSWER_LEN
)

# %%
train_encoder_input.shape, train_decoder_input.shape, train_decoder_target.shape
# Out:
# ((40500, 7), (40500, 4), (40500, 4))

# %% [markdown]
# ## 모델 생성: `Seq2Seq`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 하이퍼 파라미터 설정
BATCH_SIZE = 128
LEARNING_RATE = 0.01
MAX_EPOCHS = 50
EMBEDDING_DIM = 16
HIDDEN_SIZE = 128

MAX_ENCODER_LEN = 7  # 인코더 입력 최대 길이
MAX_DECODER_LEN = 4  # 디코더 입력 최대 길이

# %% [markdown]
# ### Encoder 구성

# %%
Image("./images/Encoder 구성.png")

# %%
# 인코더 정의
encoder_inputs = layers.Input(shape=(MAX_ENCODER_LEN,))
encoder_embedding_layer = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)
encoder_embeddings = encoder_embedding_layer(encoder_inputs)

encoder_lstm_layer = layers.LSTM(units=HIDDEN_SIZE, return_state=True)
_, encoder_state_h, encoder_state_c = encoder_lstm_layer(encoder_embeddings)
encoder_state = [encoder_state_h, encoder_state_c]
encoder_model = tf.keras.Model(inputs=encoder_inputs, outputs=encoder_state)
encoder_model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_26 (InputLayer)       [(None, 7)]               0
#
#  embedding_5 (Embedding)     (None, 7, 16)             208
#
#  lstm_5 (LSTM)               [(None, 128),             74240
#                               (None, 128),
#                               (None, 128)]
#
# =================================================================
# Total params: 74,448
# Trainable params: 74,448
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Decoder 구성

# %%
Image('./images/Decoder 구성.png')

# %%
# 디코더 정의
decoder_inputs = layers.Input(shape=(MAX_DECODER_LEN,))
decoder_embedding_layer = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)
decoder_embeddings = decoder_embedding_layer(decoder_inputs)

decoder_lstm_layer = layers.LSTM(units=HIDDEN_SIZE, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm_layer(decoder_embeddings, initial_state=encoder_state)

decoder_dense_layer = layers.Dense(VOCAB_SIZE, activation='softmax')
outputs = decoder_dense_layer(decoder_outputs)

decoder_model = tf.keras.Model(inputs=[encoder_state, decoder_inputs], outputs=outputs)
decoder_model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_27 (InputLayer)          [(None, 4)]          0           []
#
#  embedding_6 (Embedding)        (None, 4, 16)        208         ['input_27[0][0]']
#
#  input_28 (InputLayer)          [(None, 128)]        0           []
#
#  input_29 (InputLayer)          [(None, 128)]        0           []
#
#  lstm_6 (LSTM)                  [(None, 4, 128),     74240       ['embedding_6[1][0]',
#                                  (None, 128),                     'input_28[0][0]',
#                                  (None, 128)]                     'input_29[0][0]']
#
#  dense_2 (Dense)                (None, 4, 13)        1677        ['lstm_6[1][0]']
#
# ==================================================================================================
# Total params: 76,125
# Trainable params: 76,125
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Seq2Seq 모델

# %%
# Seq2Seq 모델

Seq2Seq = tf.keras.Model(inputs=[encoder_inputs, decoder_inputs], outputs=outputs)
Seq2Seq.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_26 (InputLayer)          [(None, 7)]          0           []
#
#  input_27 (InputLayer)          [(None, 4)]          0           []
#
#  embedding_5 (Embedding)        (None, 7, 16)        208         ['input_26[0][0]']
#
#  embedding_6 (Embedding)        (None, 4, 16)        208         ['input_27[0][0]']
#
#  lstm_5 (LSTM)                  [(None, 128),        74240       ['embedding_5[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_6 (LSTM)                  [(None, 4, 128),     74240       ['embedding_6[0][0]',
#                                  (None, 128),                     'lstm_5[0][1]',
#                                  (None, 128)]                     'lstm_5[0][2]']
#
#  dense_2 (Dense)                (None, 4, 13)        1677        ['lstm_6[0][0]']
#
# ==================================================================================================
# Total params: 150,573
# Trainable params: 150,573
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## 모델 설정 (손실함수, 옵티마이저 선택)

# %%
Seq2Seq.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## 모델 훈련

# %% [markdown]
# - 입력 데이터 순서 그대로

# %%
history = Seq2Seq.fit(
    [train_encoder_input, train_decoder_input],
    np.expand_dims(train_decoder_target, -1),  # (batch, timesteps, 1) 형태로 변환
    batch_size=BATCH_SIZE,
    epochs=MAX_EPOCHS,
    validation_data=(
        [val_encoder_input, val_decoder_input],
        np.expand_dims(val_decoder_target, -1)
    )
)
# Out:
# Epoch 1/50
# 317/317 [==============================] - 10s 14ms/step - loss: 1.8595 - accuracy: 0.3301 - val_loss: 1.7568 - val_accuracy: 0.3420
# Epoch 2/50
# 317/317 [==============================] - 4s 14ms/step - loss: 1.7174 - accuracy: 0.3532 - val_loss: 1.6959 - val_accuracy: 0.3589
# Epoch 3/50
# 317/317 [==============================] - 4s 14ms/step - loss: 1.6673 - accuracy: 0.3672 - val_loss: 1.5857 - val_accuracy: 0.3916
# Epoch 4/50
# 317/317 [==============================] - 5s 16ms/step - loss: 1.4505 - accuracy: 0.4468 - val_loss: 1.3385 - val_accuracy: 0.4888
# Epoch 5/50
# 317/317 [==============================] - 5s 15ms/step - loss: 1.2538 - accuracy: 0.5333 - val_loss: 1.1937 - val_accuracy: 0.5532
# Epoch 46/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.2943 - accuracy: 0.8849 - val_loss: 0.2992 - val_accuracy: 0.8848
# Epoch 47/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.3010 - accuracy: 0.8773 - val_loss: 0.3183 - val_accuracy: 0.8611
# Epoch 48/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.2922 - accuracy: 0.8849 - val_loss: 0.3398 - val_accuracy: 0.8529
# Epoch 49/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.2960 - accuracy: 0.8816 - val_loss: 0.2771 - val_accuracy: 0.8969
# Epoch 50/50
# 317/317 [==============================] - 5s 15ms/step - loss: 0.2696 - accuracy: 0.8996 - val_loss: 0.2761 - val_accuracy: 0.8939

# %% [markdown]
# - 입력 데이터 반전

# %%
history = Seq2Seq.fit(
    [train_encoder_input, train_decoder_input],
    np.expand_dims(train_decoder_target, -1),  # (batch, timesteps, 1) 형태로 변환
    batch_size=BATCH_SIZE,
    epochs=MAX_EPOCHS,
    validation_data=(
        [val_encoder_input, val_decoder_input],
        np.expand_dims(val_decoder_target, -1)
    )
)
# Out:
# Epoch 1/50
# 317/317 [==============================] - 7s 15ms/step - loss: 1.8665 - accuracy: 0.3297 - val_loss: 1.7546 - val_accuracy: 0.3463
# Epoch 2/50
# 317/317 [==============================] - 4s 11ms/step - loss: 1.7185 - accuracy: 0.3516 - val_loss: 1.6681 - val_accuracy: 0.3599
# Epoch 3/50
# 317/317 [==============================] - 4s 13ms/step - loss: 1.6201 - accuracy: 0.3765 - val_loss: 1.5540 - val_accuracy: 0.4022
# Epoch 4/50
# 317/317 [==============================] - 5s 16ms/step - loss: 1.4555 - accuracy: 0.4467 - val_loss: 1.3590 - val_accuracy: 0.4861
# Epoch 5/50
# 317/317 [==============================] - 5s 16ms/step - loss: 1.2522 - accuracy: 0.5408 - val_loss: 1.1616 - val_accuracy: 0.5811
# Epoch 6/50
# 317/317 [==============================] - 4s 14ms/step - loss: 1.0612 - accuracy: 0.6164 - val_loss: 0.9674 - val_accuracy: 0.6588
# Epoch 7/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.8747 - accuracy: 0.6894 - val_loss: 0.7901 - val_accuracy: 0.7239
# Epoch 8/50
# 317/317 [==============================] - 5s 15ms/step - loss: 0.7165 - accuracy: 0.7440 - val_loss: 0.6233 - val_accuracy: 0.7818
# Epoch 9/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.5419 - accuracy: 0.8113 - val_loss: 0.4618 - val_accuracy: 0.8424
# Epoch 10/50
# 317/317 [==============================] - 5s 15ms/step - loss: 0.3645 - accuracy: 0.8908 - val_loss: 0.3033 - val_accuracy: 0.9142
# Epoch 11/50
# 317/317 [==============================] - 6s 19ms/step - loss: 0.2422 - accuracy: 0.9427 - val_loss: 0.2028 - val_accuracy: 0.9572
# Epoch 12/50
# 317/317 [==============================] - 5s 17ms/step - loss: 0.1660 - accuracy: 0.9675 - val_loss: 0.1417 - val_accuracy: 0.9719
# Epoch 13/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.0049 - accuracy: 0.9995 - val_loss: 0.0065 - val_accuracy: 0.9988
# Epoch 34/50
# 317/317 [==============================] - 5s 15ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0078 - val_accuracy: 0.9978
# Epoch 35/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.0310 - accuracy: 0.9899 - val_loss: 0.0215 - val_accuracy: 0.9934
# Epoch 36/50
# 317/317 [==============================] - 6s 19ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.0062 - val_accuracy: 0.9988
# Epoch 37/50
# 317/317 [==============================] - 5s 15ms/step - loss: 0.0026 - accuracy: 0.9999 - val_loss: 0.0040 - val_accuracy: 0.9992
# Epoch 38/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0042 - val_accuracy: 0.9994
# Epoch 39/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0278 - accuracy: 0.9911 - val_loss: 0.0258 - val_accuracy: 0.9924
# Epoch 40/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0063 - accuracy: 0.9988 - val_loss: 0.0048 - val_accuracy: 0.9992
# Epoch 41/50
# 317/317 [==============================] - 6s 18ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.0039 - val_accuracy: 0.9994
# Epoch 42/50
# 317/317 [==============================] - 5s 17ms/step - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0032 - val_accuracy: 0.9996
# Epoch 43/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0266 - accuracy: 0.9918 - val_loss: 0.0934 - val_accuracy: 0.9687
# Epoch 44/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.0042 - val_accuracy: 0.9993
# Epoch 45/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0031 - val_accuracy: 0.9996
# Epoch 46/50
# 317/317 [==============================] - 4s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9994
# Epoch 47/50
# 317/317 [==============================] - 5s 16ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.0600 - val_accuracy: 0.9822
# Epoch 48/50
# 317/317 [==============================] - 5s 14ms/step - loss: 0.0120 - accuracy: 0.9963 - val_loss: 0.0035 - val_accuracy: 0.9995
# Epoch 49/50
# 317/317 [==============================] - 5s 15ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.0029 - val_accuracy: 0.9996
# Epoch 50/50
# 317/317 [==============================] - 5s 14ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9995

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(history.history['loss'], label='train_loss')
ax1.plot(history.history['val_loss'], label='val_loss')
ax1.legend()

# accuracies
ax2.plot(history.history['accuracy'], label='train_acc')
ax2.plot(history.history['val_accuracy'], label='val_acc')
ax2.legend()
plt.show()

# %% [markdown]
# ## 모델 예측

# %%
Image("./images/Decoder 추론(생성).png")

# %%
decoder_state_input_h = layers.Input(shape=(HIDDEN_SIZE,))
decoder_state_input_c = layers.Input(shape=(HIDDEN_SIZE,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_inputs_single = layers.Input(shape=(1,))
decoder_inputs_emb_single = decoder_embedding_layer(decoder_inputs_single)  # (batch_size, 1, EMBEDDING_DIM)

lstm_outputs, decoder_state_h, decoder_state_c = decoder_lstm_layer(
    decoder_inputs_emb_single, initial_state=decoder_states_inputs
)

decoder_states = [decoder_state_h, decoder_state_c]

decoder_outputs = decoder_dense_layer(lstm_outputs)

inf_decoder_model = Model(
    inputs = [decoder_inputs_single] + decoder_states_inputs,
    outputs = [decoder_outputs] + decoder_states
)

# %%
def predict_sequence(input_seq, max_decoder_len=MAX_DECODER_LEN):
    states_value = encoder_model.predict(input_seq, verbose=0)
    start_token = vocab.char_to_id['_']
    target_seq = np.array([[start_token]])
    decoded_sequence = []

    for _ in range(max_decoder_len):
        outputs = inf_decoder_model.predict([target_seq] + states_value, verbose=0)
        output_tokens, h, c = outputs[0], outputs[1], outputs[2]
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        decoded_sequence.append(sampled_token_index)


        target_seq = np.array([[sampled_token_index]])
        states_value = [h, c]

    # 문자열로 변환
    question = ''.join([vocab.id_to_char.get(idx, '') for idx in input_seq.flatten()])
    guess = ''.join([vocab.id_to_char.get(idx, '') for idx in decoded_sequence])

    return guess

# %%
test_question = "37+25  "
reversed_question = test_question[::-1]  # 입력 순서 반전
question_seq = [vocab.char_to_id.get(c, 0) for c in reversed_question]  # 0=UNK
question_padded = pad_sequences([question_seq], maxlen=MAX_ENCODER_LEN, padding='post')
prediction = predict_sequence(question_padded)
print(f"Question: {test_question}, Prediction: {prediction}")
# Out:
# Question: 37+25  , Prediction: 62

# %% [markdown]
# ## 모델 평가

# %%
# 전체 시퀀스 정확도 계산 함수
def calculate_sequence_accuracy(encoder_input, decoder_target, vocab, max_decoder_len=MAX_DECODER_LEN):
    correct_count = 0
    total_count = len(encoder_input)

    for i in range(total_count):
        # 예측
        input_seq = encoder_input[i:i+1]
        predicted_seq = predict_sequence(input_seq)

        # 실제 정답 디코딩
        actual_tokens = []
        for idx in decoder_target[i]:
            actual_tokens.append(vocab.id_to_char.get(idx, ''))
        actual_answer = ''.join(actual_tokens)

        print('정답: ' , actual_answer)
        print('예측: ', predicted_seq)

        # 완전 일치 검사
        if actual_answer == predicted_seq:
            correct_count += 1
    print(correct_count)
    return correct_count / total_count

# 검증 데이터로 평가
val_accuracy = calculate_sequence_accuracy(
    test_encoder_input[:10],
    test_decoder_target[:10],
    vocab,

)
# Out:
# 정답:  745
# 예측:  745
# 정답:  984
# 예측:  984
# 정답:  625
# 예측:  625
# 정답:  817
# 예측:  817
# 정답:  221
# 예측:  221
# 정답:  192
# 예측:  192
# 정답:  816
# 예측:  816
# 정답:  1056
# 예측:  1056
# 정답:  24
# 예측:  24
# 정답:  960
# 예측:  960
# 10
# 시퀀스 전체 정확도: 1.0000

# %%
# 테스트 데이터로 모델 평가
test_loss, test_accuracy = Seq2Seq.evaluate(
    [test_encoder_input, test_decoder_input],
    np.expand_dims(test_decoder_target, -1),
    batch_size=BATCH_SIZE,
    verbose=1
)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Token Accuracy: {test_accuracy:.4f}")
# Out:
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 0.9995
# Test Loss: 0.0022
# Test Token Accuracy: 0.9995
